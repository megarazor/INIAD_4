# %%
import json
import pandas as pd
import folium

# %%
csv_in1 = 'dm-mid-p1-1.csv'
html_out1 = 'dm-mid-p1-1.html'
geo = 'japan.json'

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
df1 = pd.read_csv(csv_in1, delimiter=',', skiprows=0, header=0)
print(df1.shape)
display(df1.head())
print(df1.info())
# Out:
# (47, 4)
#   prefecture  high_total  high_male  high_female
# 0   Hokkaido        8408       6663         1745
# 1     Aomori        2092       1429          663
# 2      Iwate        2339       1635          704
# 3     Miyagi        3341       2503          838
# 4      Akita        1876       1264          612
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   prefecture   47 non-null     object
#  1   high_total   47 non-null     int64
#  2   high_male    47 non-null     int64
#  3   high_female  47 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.6+ KB
# None

# %%
m = folium.Map(location=[38,135], zoom_start=5)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
folium.Choropleth(
    geo_data=geo,
    key_on='feature.properties.name',
    data=df,
    columns=['prefecture', 'high_male'],
    fill_color='BuPu',
    legend_name='#Arrested'
).add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
m.save(outfile=html_out1)

# %%
csv_in2 = 'dm-mid-p1-2.csv'

# %%
df2 = pd.read_csv(csv_in2, delimiter=',', skiprows=0, header=0)
print(df2.shape)
display(df2.head())
print(df2.info())
# Out:
# (48, 2)
#        pref        pop
# 0       All  128057352
# 1     Tokyo   13159388
# 2  Kanagawa    9048331
# 3     Osaka    8865245
# 4     Aichi    7410719
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pref    48 non-null     object
#  1   pop     48 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 896.0+ bytes
# None

# %%
df = pd.merge(df1, df2, left_on='prefecture', right_on='pref', how='inner')
print(df.shape)
display(df.head())
print(df.info())
# Out:
# (47, 6)
#   prefecture  high_total  high_male  high_female      pref      pop
# 0   Hokkaido        8408       6663         1745  Hokkaido  5506419
# 1     Aomori        2092       1429          663    Aomori  1373339
# 2      Iwate        2339       1635          704     Iwate  1330147
# 3     Miyagi        3341       2503          838    Miyagi  2348165
# 4      Akita        1876       1264          612     Akita  1085997
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 0 to 46
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   prefecture   47 non-null     object
#  1   high_total   47 non-null     int64
#  2   high_male    47 non-null     int64
#  3   high_female  47 non-null     int64
#  4   pref         47 non-null     object
#  5   pop          47 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 2.6+ KB
# None

# %%
html_out2 = 'dm-mid-p1-2.html'

# %%
df['pop_per_high_total'] = df['pop'] / df['high_total']

# %%
m = folium.Map(location=[38,135], zoom_start=5)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
folium.Choropleth(
    geo_data=geo,
    key_on='feature.properties.name',
    data=df,
    columns=['prefecture', 'pop_per_high_total'],
    fill_color='BuPu',
    legend_name='#Arrested'
).add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
m.save(outfile=html_out2)
